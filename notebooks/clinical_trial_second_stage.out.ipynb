# %% [markdown]
# # Second Stage

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# # First stage report

# %%
load("../data/data.RData")

# %%
second_stage_data_raw |>
  select(trt, outcome, bmi, diabetis) |>
  tbl_summary()
# Out:
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------
#   [**Characteristic**]{.quarto-scaffold}                                            [**N = 60**]{.quarto-scaffold}[^1^]{.gt_footnote_marks
#                                                                                     style="white-space:nowrap;font-style:italic;font-weight:normal;line-height:0;"}
#   --------------------------------------------------------------------------------- ---------------------------------------------------------------------------------
#   trt                                                                               \
#
#       case                                                                          30 (50%)
#
#       control                                                                       30 (50%)
#
#   outcome                                                                           \
#
#       close                                                                         34 (57%)
#
#       open                                                                          26 (43%)
#
#   bmi                                                                               32 (26, 36)
#
#   diabetis                                                                          24 (40%)
#
#   [^1^]{.gt_footnote_marks
#   style="white-space:nowrap;font-style:italic;font-weight:normal;line-height:0;"}
#   [n (%); Median (Q1, Q3)]{.quarto-scaffold}
#   -------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
ggstatsplot::ggbetweenstats(
  data = second_stage_data_raw,
  x = trt,
  y = bmi,
  pairwise.display = "p-value",
  p.adjust.method = "bonferroni",
  var.equal = TRUE,
  title = "BMI by treatment group"
)
